# %% [markdown]
# # Investigation 4: Test Feature Pair Interactions
#
# **Mystery**: Why do individual features help but combining them hurts?
#
# **The Paradox**:
# - Vegas Spread alone: +1.2% (68.0%)
# - Momentum alone: +0.8% (67.6%)
# - Temporal alone: +0.4% (67.2%)
# - **Expected combined**: ~+2.4%
# - **Actual combined (Full Week 10+)**: -1.6% (65.2%)
# - **Gap**: -4.0 percentage points lost to interaction!
#
# **Test Plan**: Test all important pairwise combinations to identify conflicts

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier, VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.calibration import CalibratedClassifierCV
from sklearn.feature_selection import RFECV
from sklearn.metrics import accuracy_score, brier_score_loss, roc_auc_score
from xgboost import XGBClassifier
import warnings
warnings.filterwarnings('ignore')

print('Libraries loaded')
